# %%
import os

from kiara import Kiara
from kiara.utils import is_debug

os.environ["DEBUG"] = "true"

kiara = Kiara.instance()

module_info = kiara.get_module_info("import_local_folder")
kiara.explain(module_info)

workflow = kiara.create_workflow("import_local_folder")
workflow.inputs.path = "/home/markus/projects/dharpa/notebooks/TopicModelling/data_tm_workflow"

kiara.explain(workflow.outputs)
kiara.explain(workflow.outputs.file_bundle)
# Out:
# ╭─ Module: import_local_folder ─────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   class          kiara_modules.default.data_onboarding.ImportLocalFolderModule            │
# │                                                                                           │
# │   is pipeline    no                                                                       │
# │                                                                                           │
# │   doc            -- n/a --                                                                │
# │                                                                                           │
# │   source repo    ]8;id=1620399278.974368-221195;https://dharpa.org/kiara_modules.default/api_reference/kiara_modules.default.data_onboarding/#kiara_modules.default.data_onboarding.ImportLocalFolderModule\kiara_modules.default.import_local_folder]8;;\                                │
# │                                                                                           │
# │   config class   kiara_modules.default.data_onboarding.ImportLocalPathConfig              │
# │                                                                                           │
# │   config          ────────────────────────────────────────────────────────────────────    │
# │                    constants             object    Value constants for this module.       │
# │                    source_is_immutable   boolean   Whether the data that lives in         │
# │                                                    source path can be relied upon to      │
# │                                                    not change, and always be              │
# │                                                    available                              │
# │                   ────────────────────────────────────────────────────────────────────    │
# │                                                                                           │
# │   src            def process(self, inputs: StepInputs, outputs: StepOutputs) -> None:     │
# │                                                                                           │
# │                      path = inputs.path                                                   │
# │                                                                                           │
# │                      included_files = inputs.included_files                               │
# │                      excluded_dirs = inputs.excluded_dirs                                 │
# │                                                                                           │
# │                      import_config = FolderImportConfig(include_files=included_files, …   │
# │                                                                                           │
# │                      bundle = FileBundleModel.import_folder(source=path, import_config…   │
# │                                                                                           │
# │                      outputs.file_bundle = bundle                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Value-Set: Outputs for pipeline 'import_local_folder_0' ─────────────────────────────────╮
# │                                                                                           │
# │   Field name    Type          Description                             Required   Is set   │
# │  ───────────────────────────────────────────────────────────────────────────────────────  │
# │   file_bundle   file_bundle   The collection of files contained in    yes        yes      │
# │                               the bundle.                                                 │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Value: step_output:import_local_folder_0.import_local_folder.file_bundle ────────────────╮
# │                                                                                           │
# │   id            9e905971-a0de-4a64-b651-416329db0dba                                      │
# │   type          file_bundle                                                               │
# │   desc          The collection of files contained in the bundle.                          │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   metadata      {                                                                         │
# │                   "type": {                                                               │
# │                     "orig_foldername": "data_tm_workflow",                                │
# │                     "orig_path": "/home/markus/projects/dharpa/notebooks/TopicModellin…   │
# │                     "import_time": "2021-05-07T16:54:39.261291",                          │
# │                     "number_of_files": 771,                                               │
# │                     "size": 9745316,                                                      │
# │                     "path": "/home/markus/projects/dharpa/notebooks/TopicModelling/dat…   │
# │                     "python_cls": "FileBundleModel"                                       │
# │                   }                                                                       │
# │                 }                                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
